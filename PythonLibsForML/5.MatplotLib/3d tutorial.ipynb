# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np

# %%
#%matplotlib inline
# %matplotlib notebook
# %matplotlib qt

# %% [markdown]
# for **%matplotlib qt** run following commands:
#
# `conda install qt`
#
# `conda install pyqt`

# %% [markdown]
# ### Line plots

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_aspect("equal")
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, z, label='parametric curve')
ax.legend()
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# %%
type(ax), isinstance(ax, Axes3D)

# %% [markdown]
# ### Scatter plots

# %%
plt.close()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect("equal")
n = 200

red_mu = [0, 0, 0]
red_sigma =  [[3, 1, 0],
              [1, 1, 0],
              [0, 0, 0.01]]

blue_mu = [1, 1, 0]
blue_sigma =  [[5, 0, 2],
               [0, 1, 0],
               [2, 0, 1]]

for c, m, mu, sigma in [('r', 'o', red_mu, red_sigma), 
                        ('b', '^', blue_mu, blue_sigma)]:
    
    xs, ys, zs = np.random.multivariate_normal(mu, sigma, n).T
    ax.scatter(xs, ys, zs, c=c, marker=m, alpha=0.3)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# Text(0.5,0,'Z')

# %% [markdown]
# ### Wireframe plots

# %%
plt.close()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
from mpl_toolkits.mplot3d import axes3d
X, Y, Z = axes3d.get_test_data(0.05)

# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

# %% [markdown]
# ### Surface plots

# %%
plt.close("all")

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_aspect("equal")

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

# %% [markdown]
# ### Subplotting

# %%
def f(t):
    s1 = np.cos(2*np.pi*t)
    e1 = np.exp(-t)
    return np.multiply(s1, e1)

# %%
fig = plt.figure(figsize=plt.figaspect(0.5))
################
# First subplot
################
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)
t3 = np.arange(0.0, 2.0, 0.01)

# Twice as tall as it is wide.
ax = plt.subplot(121)

l = ax.plot(t1, f(t1), 'bo',
            t2, f(t2), 'k--', markerfacecolor='green')
ax.grid(True)
ax.set_ylabel('Damped oscillation')


#################
# Second subplot
#################
ax = plt.subplot(122, projection="3d")

X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                       linewidth=0, 
                       antialiased=False)

ax.set_zlim3d(-1, 1)
# Out:
# (-1, 1)
