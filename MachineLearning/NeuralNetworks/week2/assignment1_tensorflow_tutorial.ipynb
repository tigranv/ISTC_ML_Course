# %% [markdown]
# # MNIST master
#
# For a demo we shall solve the same digit recognition problem, but at a different scale
# * images are now 28x28
# * 10 different digits
# * 50k samples

# %% [markdown]
# Before doing this homework, read some code examples written in tensorflow. There is a good repository with code examples: https://github.com/aymericdamien/TensorFlow-Examples. As we already know, we need many samples to learn :)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
# Out:
# /home/ashmat98/.miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from mnist import load_dataset
X_train,y_train,X_val,y_val,X_test,y_test = load_dataset()

print(X_train.shape,y_train.shape)
# Out:
# (50000, 1, 28, 28) (50000,)

# %%
X_train.shape
# Out:
# (50000, 1, 28, 28)

# %%
plt.imshow(-X_train[20, 0], cmap="jet")
y_train[20]
# Out:
# 4

# %%
#defining placeholders for input and target
input_X = tf.placeholder(tf.float32, shape=[None, 1, 28, 28], 
                         name="X")
target_y = tf.placeholder(tf.int32, shape=[None], 
                          name="target_Y_integer")

# %% [markdown]
# Defining network architecture

# %%
# flatten images to (batch_size x 728) matrix
input_X_reshaped = tf.reshape(input_X, shape=[-1, 1*28*28], 
                              name="reshape_X")

# Fully connected layer, that takes input layer and applies 50 neurons 
# to it. Nonlinearity here is sigmoid as in logistic regression.
# You can give a name to each layer (optional)
l1 = tf.layers.dense(input_X_reshaped, units=50, 
                     activation=tf.nn.sigmoid)

# Fully connected output layer that takes l1 as input and has 
# 10 neurons (1 for each digit).
# This predicts scores for the classes
l2 = tf.layers.dense(l1, units=10, activation=None)

# We use softmax nonlinearity to make probabilities add up to 1
l_out = tf.nn.softmax(l2)

# Prediction
y_predicted = tf.argmax(l2, axis=-1)

# %%
weights = tf.trainable_variables()
weights
# Out:
# [<tf.Variable 'dense/kernel:0' shape=(784, 50) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(50,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(50, 10) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(10,) dtype=float32_ref>]

# %% [markdown]
# ### Than you could simply
# * define loss function manually
# * compute error gradient over all weights
# * define updates
# * But that's a whole lot of work and life's short
#   * not to mention life's too short to wait for SGD to converge
#
# Instead, we shall use Tensorflow builtins

# %%
# Mean categorical crossentropy as a loss function
# - similar to logistic loss but for multiclass targets
loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
    labels=target_y, logits=l2, name="softmax_loss"))

# %%
accuracy, update_accuracy = tf.metrics.accuracy(target_y, y_predicted)
tf.local_variables()
# Out:
# [<tf.Variable 'accuracy/total:0' shape=() dtype=float32_ref>,
#  <tf.Variable 'accuracy/count:0' shape=() dtype=float32_ref>]

# %%
optimzer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train_step = optimzer.minimize(loss)

# %% [markdown]
# ### That's all, now let's train it!
# * We got a lot of data, so it's recommended that you use SGD
# * So let's implement a function that splits the training sample into minibatches

# %%
# An auxilary function that returns mini-batches for neural network training

#Parameters
# inputs - a tensor of images with shape (many, 1, 28, 28), e.g. X_train
# outputs - a vector of answers for corresponding images e.g. Y_train
#batch_size - a single number - the intended size of each batches

def iterate_minibatches(inputs, targets, batchsize):
    assert len(inputs) == len(targets)
    indices = np.arange(len(inputs))
    np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        excerpt = indices[start_idx:start_idx + batchsize]
        yield inputs[excerpt], targets[excerpt]

# %% [markdown]
# # Training loop

# %% [markdown]
# Model saver.
# <br>
# See more:
# http://cv-tricks.com/tensorflow-tutorial/save-restore-tensorflow-models-quick-complete-tutorial/

# %%
model_path = "./checkpoints/model.ckpt"
saver = tf.train.Saver(max_to_keep=3)

# %%
import time

num_epochs = 100 # amount of passes through the data

batch_size = 50 # number of samples processed at each function call

with tf.Session() as sess:
    # initialize global wariables
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(num_epochs):
        # In each epoch, we do a full pass over the training data:
        train_err = 0
        train_batches = 0
        start_time = time.time()

        sess.run(tf.local_variables_initializer())
        for batch in iterate_minibatches(X_train, y_train,batch_size):
            inputs, targets = batch

            _, train_err_batch, _ = sess.run(
                [train_step, loss, update_accuracy], 
                feed_dict={input_X: inputs, target_y:targets}
            )
            train_err += train_err_batch
            train_batches += 1
        train_acc = sess.run(accuracy)

        # And a full pass over the validation data:
        sess.run(tf.local_variables_initializer())
        for batch in iterate_minibatches(X_val, y_val, batch_size):
            inputs, targets = batch
            sess.run(update_accuracy, feed_dict={input_X: inputs, 
                                                 target_y:targets})
        val_acc = sess.run(accuracy)


        # Then we print the results for this epoch:
        print("Epoch {} of {} took {:.3f}s".format(
            epoch + 1, num_epochs, time.time() - start_time))

        print("  training loss (in-iteration):\t\t{:.6f}".format(train_err / train_batches))
        print("  train accuracy:\t\t{:.2f} %".format(
            train_acc * 100))
        print("  validation accuracy:\t\t{:.2f} %".format(
            val_acc * 100))
        
        # save model
        save_path = saver.save(sess, model_path, global_step=epoch)
        print("  Model saved in file: %s" % save_path)
# Out:
# Epoch 1 of 100 took 2.053s
#   training loss (in-iteration):		1.853357
#   train accuracy:		59.01 %
#   validation accuracy:		76.75 %
#   Model saved in file: ./checkpoints/model.ckpt-0
# Epoch 2 of 100 took 1.701s
#   training loss (in-iteration):		1.187282
#   train accuracy:		78.11 %
#   validation accuracy:		83.84 %
#   Model saved in file: ./checkpoints/model.ckpt-1
# Epoch 3 of 100 took 1.749s
#   training loss (in-iteration):		0.852740
#   train accuracy:		82.77 %
#   validation accuracy:		86.50 %
#   Model saved in file: ./checkpoints/model.ckpt-2
# Epoch 4 of 100 took 2.149s
#   training loss (in-iteration):		0.688422
#   train accuracy:		84.98 %
#   validation accuracy:		87.58 %
#   Model saved in file: ./checkpoints/model.ckpt-3
# Epoch 5 of 100 took 1.622s
#   training loss (in-iteration):		0.594161
#   train accuracy:		86.34 %
#   validation accuracy:		88.55 %
#   Model saved in file: ./checkpoints/model.ckpt-4
# Epoch 6 of 100 took 1.705s
#   training loss (in-iteration):		0.532998
#   train accuracy:		87.23 %
#   validation accuracy:		89.34 %
#   Model saved in file: ./checkpoints/model.ckpt-5
# Epoch 7 of 100 took 2.091s
#   training loss (in-iteration):		0.489984
#   train accuracy:		87.92 %
#   validation accuracy:		89.65 %
#   Model saved in file: ./checkpoints/model.ckpt-6
# Epoch 8 of 100 took 1.940s
#   training loss (in-iteration):		0.458157
#   train accuracy:		88.38 %
#   validation accuracy:		90.11 %
#   Model saved in file: ./checkpoints/model.ckpt-7
# Epoch 9 of 100 took 1.652s
#   training loss (in-iteration):		0.433607
#   train accuracy:		88.73 %
#   validation accuracy:		90.44 %
#   Model saved in file: ./checkpoints/model.ckpt-8
# Epoch 10 of 100 took 1.659s
#   training loss (in-iteration):		0.414104
#   train accuracy:		89.08 %
#   validation accuracy:		90.61 %
#   Model saved in file: ./checkpoints/model.ckpt-9
# Epoch 11 of 100 took 1.904s
#   training loss (in-iteration):		0.398215
#   train accuracy:		89.34 %
#   validation accuracy:		90.65 %
#   Model saved in file: ./checkpoints/model.ckpt-10
# Epoch 12 of 100 took 1.421s
#   training loss (in-iteration):		0.384858
#   train accuracy:		89.65 %
#   validation accuracy:		90.92 %
#   Model saved in file: ./checkpoints/model.ckpt-11
# Epoch 13 of 100 took 1.512s
#   training loss (in-iteration):		0.373451
#   train accuracy:		89.89 %
#   validation accuracy:		91.02 %
#   Model saved in file: ./checkpoints/model.ckpt-12
# Epoch 14 of 100 took 1.714s
#   training loss (in-iteration):		0.363597
#   train accuracy:		90.01 %
#   validation accuracy:		91.12 %
#   Model saved in file: ./checkpoints/model.ckpt-13
# Epoch 15 of 100 took 1.479s
#   training loss (in-iteration):		0.354810
#   train accuracy:		90.20 %
#   validation accuracy:		91.14 %
#   Model saved in file: ./checkpoints/model.ckpt-14
# Epoch 16 of 100 took 1.332s
#   training loss (in-iteration):		0.347132
#   train accuracy:		90.37 %
#   validation accuracy:		91.31 %
#   Model saved in file: ./checkpoints/model.ckpt-15
# Epoch 17 of 100 took 1.701s
#   training loss (in-iteration):		0.340153
#   train accuracy:		90.51 %
#   validation accuracy:		91.40 %
#   Model saved in file: ./checkpoints/model.ckpt-16
# Epoch 18 of 100 took 1.609s
#   training loss (in-iteration):		0.333875
#   train accuracy:		90.69 %
#   validation accuracy:		91.48 %
#   Model saved in file: ./checkpoints/model.ckpt-17
# Epoch 19 of 100 took 1.761s
#   training loss (in-iteration):		0.328032
#   train accuracy:		90.82 %
#   validation accuracy:		91.73 %
#   Model saved in file: ./checkpoints/model.ckpt-18
# Epoch 20 of 100 took 2.256s
#   training loss (in-iteration):		0.322708
#   train accuracy:		90.97 %
#   validation accuracy:		91.79 %
#   Model saved in file: ./checkpoints/model.ckpt-19
# Epoch 21 of 100 took 1.560s
#   training loss (in-iteration):		0.317689
#   train accuracy:		91.05 %
#   validation accuracy:		91.88 %
#   Model saved in file: ./checkpoints/model.ckpt-20
# Epoch 22 of 100 took 1.931s
#   training loss (in-iteration):		0.313057
#   train accuracy:		91.20 %
#   validation accuracy:		91.93 %
#   Model saved in file: ./checkpoints/model.ckpt-21
# Epoch 23 of 100 took 1.755s
#   training loss (in-iteration):		0.308791
#   train accuracy:		91.29 %
#   validation accuracy:		91.96 %
#   Model saved in file: ./checkpoints/model.ckpt-22
# Epoch 24 of 100 took 1.547s
#   training loss (in-iteration):		0.304569
#   train accuracy:		91.38 %
#   validation accuracy:		92.10 %
#   Model saved in file: ./checkpoints/model.ckpt-23
# Epoch 25 of 100 took 1.554s
#   training loss (in-iteration):		0.300746
#   train accuracy:		91.47 %
#   validation accuracy:		92.22 %
#   Model saved in file: ./checkpoints/model.ckpt-24
# Epoch 26 of 100 took 1.586s
#   training loss (in-iteration):		0.297080
#   train accuracy:		91.55 %
#   validation accuracy:		92.31 %
#   Model saved in file: ./checkpoints/model.ckpt-25
# Epoch 27 of 100 took 1.699s
#   training loss (in-iteration):		0.293545
#   train accuracy:		91.67 %
#   validation accuracy:		92.36 %
#   Model saved in file: ./checkpoints/model.ckpt-26
# Epoch 28 of 100 took 1.386s
#   training loss (in-iteration):		0.290185
#   train accuracy:		91.75 %
#   validation accuracy:		92.46 %
#   Model saved in file: ./checkpoints/model.ckpt-27
# Epoch 29 of 100 took 1.571s
#   training loss (in-iteration):		0.286916
#   train accuracy:		91.83 %
#   validation accuracy:		92.50 %
#   Model saved in file: ./checkpoints/model.ckpt-28
# Epoch 30 of 100 took 1.540s
#   training loss (in-iteration):		0.283811
#   train accuracy:		91.89 %
#   validation accuracy:		92.56 %
#   Model saved in file: ./checkpoints/model.ckpt-29
# Epoch 31 of 100 took 1.430s
#   training loss (in-iteration):		0.280854
#   train accuracy:		91.97 %
#   validation accuracy:		92.64 %
#   Model saved in file: ./checkpoints/model.ckpt-30
# Epoch 32 of 100 took 1.548s
#   training loss (in-iteration):		0.277951
#   train accuracy:		92.06 %
#   validation accuracy:		92.75 %
#   Model saved in file: ./checkpoints/model.ckpt-31
# Epoch 33 of 100 took 1.573s
#   training loss (in-iteration):		0.275147
#   train accuracy:		92.13 %
#   validation accuracy:		92.80 %
#   Model saved in file: ./checkpoints/model.ckpt-32
# Epoch 34 of 100 took 1.416s
#   training loss (in-iteration):		0.272490
#   train accuracy:		92.21 %
#   validation accuracy:		92.86 %
#   Model saved in file: ./checkpoints/model.ckpt-33
# Epoch 35 of 100 took 1.493s
#   training loss (in-iteration):		0.269841
#   train accuracy:		92.29 %
#   validation accuracy:		92.90 %
#   Model saved in file: ./checkpoints/model.ckpt-34
# Epoch 36 of 100 took 1.518s
#   training loss (in-iteration):		0.267279
#   train accuracy:		92.37 %
#   validation accuracy:		92.99 %
#   Model saved in file: ./checkpoints/model.ckpt-35
# Epoch 37 of 100 took 1.564s
#   training loss (in-iteration):		0.264773
#   train accuracy:		92.42 %
#   validation accuracy:		92.95 %
#   Model saved in file: ./checkpoints/model.ckpt-36
# Epoch 38 of 100 took 1.534s
#   training loss (in-iteration):		0.262373
#   train accuracy:		92.50 %
#   validation accuracy:		93.13 %
#   Model saved in file: ./checkpoints/model.ckpt-37
# Epoch 39 of 100 took 1.440s
#   training loss (in-iteration):		0.260075
#   train accuracy:		92.58 %
#   validation accuracy:		93.12 %
#   Model saved in file: ./checkpoints/model.ckpt-38
# Epoch 40 of 100 took 1.728s
#   training loss (in-iteration):		0.257778
#   train accuracy:		92.60 %
#   validation accuracy:		93.18 %
#   Model saved in file: ./checkpoints/model.ckpt-39
# Epoch 41 of 100 took 1.674s
#   training loss (in-iteration):		0.255545
#   train accuracy:		92.68 %
#   validation accuracy:		93.25 %
#   Model saved in file: ./checkpoints/model.ckpt-40
# Epoch 42 of 100 took 1.701s
#   training loss (in-iteration):		0.253303
#   train accuracy:		92.75 %
#   validation accuracy:		93.36 %
#   Model saved in file: ./checkpoints/model.ckpt-41
# Epoch 43 of 100 took 1.652s
#   training loss (in-iteration):		0.251237
#   train accuracy:		92.81 %
#   validation accuracy:		93.35 %
#   Model saved in file: ./checkpoints/model.ckpt-42
# Epoch 44 of 100 took 1.545s
#   training loss (in-iteration):		0.249181
#   train accuracy:		92.86 %
#   validation accuracy:		93.44 %
#   Model saved in file: ./checkpoints/model.ckpt-43
# Epoch 45 of 100 took 1.522s
#   training loss (in-iteration):		0.247091
#   train accuracy:		92.91 %
#   validation accuracy:		93.51 %
#   Model saved in file: ./checkpoints/model.ckpt-44
# Epoch 46 of 100 took 1.688s
#   training loss (in-iteration):		0.245111
#   train accuracy:		93.01 %
#   validation accuracy:		93.56 %
#   Model saved in file: ./checkpoints/model.ckpt-45
# Epoch 47 of 100 took 1.550s
#   training loss (in-iteration):		0.243186
#   train accuracy:		93.07 %
#   validation accuracy:		93.57 %
#   Model saved in file: ./checkpoints/model.ckpt-46
# Epoch 48 of 100 took 1.744s
#   training loss (in-iteration):		0.241218
#   train accuracy:		93.13 %
#   validation accuracy:		93.57 %
#   Model saved in file: ./checkpoints/model.ckpt-47
# Epoch 49 of 100 took 1.889s
#   training loss (in-iteration):		0.239338
#   train accuracy:		93.15 %
#   validation accuracy:		93.65 %
#   Model saved in file: ./checkpoints/model.ckpt-48
# Epoch 50 of 100 took 1.709s
#   training loss (in-iteration):		0.237520
#   train accuracy:		93.22 %
#   validation accuracy:		93.61 %
#   Model saved in file: ./checkpoints/model.ckpt-49
# Epoch 51 of 100 took 1.739s
#   training loss (in-iteration):		0.235726
#   train accuracy:		93.25 %
#   validation accuracy:		93.75 %
#   Model saved in file: ./checkpoints/model.ckpt-50
# Epoch 52 of 100 took 1.535s
#   training loss (in-iteration):		0.233945
#   train accuracy:		93.37 %
#   validation accuracy:		93.68 %
#   Model saved in file: ./checkpoints/model.ckpt-51
# Epoch 53 of 100 took 1.671s
#   training loss (in-iteration):		0.232185
#   train accuracy:		93.40 %
#   validation accuracy:		93.73 %
#   Model saved in file: ./checkpoints/model.ckpt-52
# Epoch 54 of 100 took 1.393s
#   training loss (in-iteration):		0.230500
#   train accuracy:		93.42 %
#   validation accuracy:		93.78 %
#   Model saved in file: ./checkpoints/model.ckpt-53
# Epoch 55 of 100 took 2.198s
#   training loss (in-iteration):		0.228802
#   train accuracy:		93.47 %
#   validation accuracy:		93.78 %
#   Model saved in file: ./checkpoints/model.ckpt-54
# Epoch 56 of 100 took 2.081s
#   training loss (in-iteration):		0.227216
#   train accuracy:		93.52 %
#   validation accuracy:		93.91 %
#   Model saved in file: ./checkpoints/model.ckpt-55
# Epoch 57 of 100 took 1.581s
#   training loss (in-iteration):		0.225543
#   train accuracy:		93.53 %
#   validation accuracy:		93.97 %
#   Model saved in file: ./checkpoints/model.ckpt-56
# Epoch 58 of 100 took 1.543s
#   training loss (in-iteration):		0.223966
#   train accuracy:		93.59 %
#   validation accuracy:		93.85 %
#   Model saved in file: ./checkpoints/model.ckpt-57
# Epoch 59 of 100 took 1.457s
#   training loss (in-iteration):		0.222334
#   train accuracy:		93.62 %
#   validation accuracy:		94.01 %
#   Model saved in file: ./checkpoints/model.ckpt-58
# Epoch 60 of 100 took 1.536s
#   training loss (in-iteration):		0.220888
#   train accuracy:		93.73 %
#   validation accuracy:		94.05 %
#   Model saved in file: ./checkpoints/model.ckpt-59
# Epoch 61 of 100 took 1.840s
#   training loss (in-iteration):		0.219282
#   train accuracy:		93.73 %
#   validation accuracy:		94.13 %
#   Model saved in file: ./checkpoints/model.ckpt-60
# Epoch 62 of 100 took 1.506s
#   training loss (in-iteration):		0.217855
#   train accuracy:		93.73 %
#   validation accuracy:		94.11 %
#   Model saved in file: ./checkpoints/model.ckpt-61
# Epoch 63 of 100 took 1.590s
#   training loss (in-iteration):		0.216379
#   train accuracy:		93.78 %
#   validation accuracy:		94.12 %
#   Model saved in file: ./checkpoints/model.ckpt-62
# Epoch 64 of 100 took 1.460s
#   training loss (in-iteration):		0.214895
#   train accuracy:		93.83 %
#   validation accuracy:		94.15 %
#   Model saved in file: ./checkpoints/model.ckpt-63
# Epoch 65 of 100 took 1.592s
#   training loss (in-iteration):		0.213486
#   train accuracy:		93.87 %
#   validation accuracy:		94.23 %
#   Model saved in file: ./checkpoints/model.ckpt-64
# Epoch 66 of 100 took 1.445s
#   training loss (in-iteration):		0.212113
#   train accuracy:		93.89 %
#   validation accuracy:		94.23 %
#   Model saved in file: ./checkpoints/model.ckpt-65
# Epoch 67 of 100 took 1.422s
#   training loss (in-iteration):		0.210721
#   train accuracy:		93.92 %
#   validation accuracy:		94.27 %
#   Model saved in file: ./checkpoints/model.ckpt-66
# Epoch 68 of 100 took 1.398s
#   training loss (in-iteration):		0.209329
#   train accuracy:		93.97 %
#   validation accuracy:		94.33 %
#   Model saved in file: ./checkpoints/model.ckpt-67
# Epoch 69 of 100 took 1.570s
#   training loss (in-iteration):		0.207937
#   train accuracy:		94.00 %
#   validation accuracy:		94.30 %
#   Model saved in file: ./checkpoints/model.ckpt-68
# Epoch 70 of 100 took 1.537s
#   training loss (in-iteration):		0.206613
#   train accuracy:		94.05 %
#   validation accuracy:		94.37 %
#   Model saved in file: ./checkpoints/model.ckpt-69
# Epoch 71 of 100 took 1.539s
#   training loss (in-iteration):		0.205370
#   train accuracy:		94.07 %
#   validation accuracy:		94.46 %
#   Model saved in file: ./checkpoints/model.ckpt-70
# Epoch 72 of 100 took 1.405s
#   training loss (in-iteration):		0.204036
#   train accuracy:		94.11 %
#   validation accuracy:		94.44 %
#   Model saved in file: ./checkpoints/model.ckpt-71
# Epoch 73 of 100 took 1.410s
#   training loss (in-iteration):		0.202821
#   train accuracy:		94.13 %
#   validation accuracy:		94.46 %
#   Model saved in file: ./checkpoints/model.ckpt-72
# Epoch 74 of 100 took 1.270s
#   training loss (in-iteration):		0.201548
#   train accuracy:		94.20 %
#   validation accuracy:		94.51 %
#   Model saved in file: ./checkpoints/model.ckpt-73
# Epoch 75 of 100 took 1.254s
#   training loss (in-iteration):		0.200288
#   train accuracy:		94.24 %
#   validation accuracy:		94.53 %
#   Model saved in file: ./checkpoints/model.ckpt-74
# Epoch 76 of 100 took 1.521s
#   training loss (in-iteration):		0.199078
#   train accuracy:		94.28 %
#   validation accuracy:		94.60 %
#   Model saved in file: ./checkpoints/model.ckpt-75
# Epoch 77 of 100 took 1.399s
#   training loss (in-iteration):		0.197872
#   train accuracy:		94.28 %
#   validation accuracy:		94.63 %
#   Model saved in file: ./checkpoints/model.ckpt-76
# Epoch 78 of 100 took 1.671s
#   training loss (in-iteration):		0.196720
#   train accuracy:		94.34 %
#   validation accuracy:		94.60 %
#   Model saved in file: ./checkpoints/model.ckpt-77
# Epoch 79 of 100 took 1.664s
#   training loss (in-iteration):		0.195494
#   train accuracy:		94.36 %
#   validation accuracy:		94.75 %
#   Model saved in file: ./checkpoints/model.ckpt-78
# Epoch 80 of 100 took 1.456s
#   training loss (in-iteration):		0.194405
#   train accuracy:		94.39 %
#   validation accuracy:		94.72 %
#   Model saved in file: ./checkpoints/model.ckpt-79
# Epoch 81 of 100 took 1.427s
#   training loss (in-iteration):		0.193238
#   train accuracy:		94.42 %
#   validation accuracy:		94.77 %
#   Model saved in file: ./checkpoints/model.ckpt-80
# Epoch 82 of 100 took 1.746s
#   training loss (in-iteration):		0.192136
#   train accuracy:		94.47 %
#   validation accuracy:		94.84 %
#   Model saved in file: ./checkpoints/model.ckpt-81
# Epoch 83 of 100 took 1.576s
#   training loss (in-iteration):		0.190979
#   train accuracy:		94.49 %
#   validation accuracy:		94.78 %
#   Model saved in file: ./checkpoints/model.ckpt-82
# Epoch 84 of 100 took 1.757s
#   training loss (in-iteration):		0.189836
#   train accuracy:		94.55 %
#   validation accuracy:		94.80 %
#   Model saved in file: ./checkpoints/model.ckpt-83
# Epoch 85 of 100 took 1.606s
#   training loss (in-iteration):		0.188791
#   train accuracy:		94.55 %
#   validation accuracy:		94.85 %
#   Model saved in file: ./checkpoints/model.ckpt-84
# Epoch 86 of 100 took 1.736s
#   training loss (in-iteration):		0.187630
#   train accuracy:		94.58 %
#   validation accuracy:		94.88 %
#   Model saved in file: ./checkpoints/model.ckpt-85
# Epoch 87 of 100 took 1.591s
#   training loss (in-iteration):		0.186661
#   train accuracy:		94.62 %
#   validation accuracy:		94.89 %
#   Model saved in file: ./checkpoints/model.ckpt-86
# Epoch 88 of 100 took 1.459s
#   training loss (in-iteration):		0.185575
#   train accuracy:		94.64 %
#   validation accuracy:		94.99 %
#   Model saved in file: ./checkpoints/model.ckpt-87
# Epoch 89 of 100 took 1.496s
#   training loss (in-iteration):		0.184600
#   train accuracy:		94.66 %
#   validation accuracy:		94.97 %
#   Model saved in file: ./checkpoints/model.ckpt-88
# Epoch 90 of 100 took 1.456s
#   training loss (in-iteration):		0.183556
#   train accuracy:		94.69 %
#   validation accuracy:		94.99 %
#   Model saved in file: ./checkpoints/model.ckpt-89
# Epoch 91 of 100 took 1.634s
#   training loss (in-iteration):		0.182569
#   train accuracy:		94.73 %
#   validation accuracy:		95.04 %
#   Model saved in file: ./checkpoints/model.ckpt-90
# Epoch 92 of 100 took 1.471s
#   training loss (in-iteration):		0.181549
#   train accuracy:		94.74 %
#   validation accuracy:		95.06 %
#   Model saved in file: ./checkpoints/model.ckpt-91
# Epoch 93 of 100 took 1.597s
#   training loss (in-iteration):		0.180535
#   train accuracy:		94.77 %
#   validation accuracy:		95.07 %
#   Model saved in file: ./checkpoints/model.ckpt-92
# Epoch 94 of 100 took 1.446s
#   training loss (in-iteration):		0.179594
#   train accuracy:		94.81 %
#   validation accuracy:		95.10 %
#   Model saved in file: ./checkpoints/model.ckpt-93
# Epoch 95 of 100 took 1.359s
#   training loss (in-iteration):		0.178596
#   train accuracy:		94.84 %
#   validation accuracy:		95.09 %
#   Model saved in file: ./checkpoints/model.ckpt-94
# Epoch 96 of 100 took 1.390s
#   training loss (in-iteration):		0.177648
#   train accuracy:		94.84 %
#   validation accuracy:		95.11 %
#   Model saved in file: ./checkpoints/model.ckpt-95
# Epoch 97 of 100 took 1.533s
#   training loss (in-iteration):		0.176731
#   train accuracy:		94.87 %
#   validation accuracy:		95.13 %
#   Model saved in file: ./checkpoints/model.ckpt-96
# Epoch 98 of 100 took 1.558s
#   training loss (in-iteration):		0.175767
#   train accuracy:		94.92 %
#   validation accuracy:		95.16 %
#   Model saved in file: ./checkpoints/model.ckpt-97
# Epoch 99 of 100 took 1.494s
#   training loss (in-iteration):		0.174909
#   train accuracy:		94.93 %
#   validation accuracy:		95.14 %
#   Model saved in file: ./checkpoints/model.ckpt-98
# Epoch 100 of 100 took 1.460s
#   training loss (in-iteration):		0.173944
#   train accuracy:		94.95 %
#   validation accuracy:		95.14 %
#   Model saved in file: ./checkpoints/model.ckpt-99

# %% [markdown]
# Now we can restore saved parameters:

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    load_path = saver.restore(sess, saver.last_checkpoints[-1])
    print("Model restored from file: %s" % save_path)
    
    sess.run(tf.local_variables_initializer())
    for batch in iterate_minibatches(X_test, y_test, 500):
        inputs, targets = batch
        sess.run(update_accuracy, feed_dict={input_X: inputs, 
                                                   target_y:targets})
    test_acc = sess.run(accuracy)
    print("Final results:")
    print("  test accuracy:\t\t{:.2f} %".format(
        test_acc* 100))

    if test_acc * 100 > 99.5:
        print ("Achievement unlocked: 80lvl Warlock!")
    else:
        print ("We need more magic!")
# Out:
# INFO:tensorflow:Restoring parameters from ./checkpoints/model.ckpt-99
# Model restored from file: ./checkpoints/model.ckpt-99
# Final results:
#   test accuracy:		94.89 %
# We need more magic!

# %% [markdown]
# # Now improve it!
#
# * Moar layers!
# * Moar units!
# * Different nonlinearities!
