# %%
import numpy as np
import numpy 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib notebook

# %%
train_data = np.load("train_images.npy")
labels = np.load("train_labels_multy.npy")
print(labels)
train_data.shape
# Out:
# [[5.]
#  [0.]
#  [4.]
#  ...
#  [5.]
#  [6.]
#  [8.]]
# (60000, 784)

# %%
labels = labels.flatten().reshape(labels.shape[0])
print(labels)
# Out:
# [5. 0. 4. ... 5. 6. 8.]

# %%
train_data = train_data / train_data.max()
train_data[0].shape
# Out:
# (784,)

# %%
x_train, x_test, y_train, y_test = train_test_split(train_data, labels, test_size=0.25, random_state=0)

# %%
def convert_labels(l):
    vector = np.zeros(10)
    vector[l] = 1
    return vector


def softmax(X, b):
    z = X.dot(b)
    z -= np.max(z)
    sm = (np.exp(z).T / np.sum(np.exp(z),axis=1)).T
    return sm


def loss(X, y, b):
    prob = softmax(X, b) 
    loss = (-1 / len(X)) * np.sum(y * np.log(prob))
    return loss


def grad (y, X, b):
    h = softmax(X, b)
    return (-1 / len(X)) * np.dot(X.T,(y - h))


def train(X, y, steps=10, lr=1e-2):
    b = np.zeros([x_train.shape[1],len(np.unique(y))])
    losses = []
    y = np.array([convert_labels(int(a)) for a in y])
    for i in range(steps):        
        gradient = grad(y, X, b)
        b = b - lr * gradient
        l = loss(X, y, b) 
        losses.append(l)
        if i % 200 == 1:
            print("step: {}, loss: {}".format(i, l))
    return b, losses

# %%
w, losses = train(x_train, y_train, steps=500)
# Out:
# step: 1, loss: 2.2811127889218006
# step: 201, loss: 1.1893317760947077
# step: 401, loss: 0.879276372054964

# %%
predictions = softmax(x_test, w)

# %%
preds = np.argmax(predictions,axis=1)

# %%
(preds == y_test).mean() * 100
# Out:
# 84.03333333333333

# %%
plt.plot(losses)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
y_test_convertedy_test_c  = np.array([convert_labels(int(a)) for a in y_test])

# %%
# loss(x_test, y_test_converted, w)
