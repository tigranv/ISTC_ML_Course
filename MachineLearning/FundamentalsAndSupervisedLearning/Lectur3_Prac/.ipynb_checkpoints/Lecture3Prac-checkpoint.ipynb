# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %%
data_train = np.load("clean_train.npy")
data_test = np.load("clean_test.npy")

df_train = pd.DataFrame(list(data_train))
df_test = pd.DataFrame(list(data_test))

print("Train data shape:", df_train.shape)
print("Test data shape:", df_test.shape)
train_number = df_train.shape[0] # to re-cut sets

target = df_train.pp
test_usernames = df_test.username 
print(target.shape)

# Lets concat test and train for data analizing and preprocessing
df = pd.concat([df_train.drop(['pp'], axis=1, inplace=False), df_test])
print("Full data shape:", df.shape)
df.head()
# Out:
# Train data shape: (6976, 28)
# Test data shape: (2994, 27)
# (6976,)
# Full data shape: (9970, 27)
#         A       S     SS   age        country  country_rank  \
# 0   651.0   803.0   28.0  16.0          Chile           1.0
# 1  1034.0   405.0  189.0  19.0         Poland           1.0
# 2   839.0   787.0   52.0  14.0  United States           1.0
# 3  1171.0   490.0   27.0   NaN      Lithuania           1.0
# 4   912.0  3450.0  234.0  22.0          China           1.0
#
#    favourite_beatmapset_count  follower_count  hit_accuracy  is_active  \
# 0                          60            9204       98.3008       True
# 1                          14           48041       98.9178       True
# 2                          10           17495       98.4025       True
# 3                          61            5413       99.0310       True
# 4                          51            5702       97.5871       True
#
#       ...                playstyle post_count  \
# 0     ...       [keyboard, tablet]          9
# 1     ...       [keyboard, tablet]         15
# 2     ...                  [touch]         10
# 3     ...        [mouse, keyboard]         17
# 4     ...       [keyboard, tablet]         94
#
#                      previous_usernames  ranked_and_approved_beatmapset_count  \
# 0                             [TrollFk]                                     0
# 1                                    []                                     0
# 2                               [Vaxei]                                     0
# 3                      [Azuren, Cainon]                                     0
# 4  [kamiyo-sama, Kamiyo-sama, Tokichii]                                     0
#
#   ranked_score  replays_watched_by_others  \
# 0  35956687428                     188557
# 1  46649498415                    1720746
# 2  29827153244                     464031
# 3  15928388241                      93667
# 4  53430781951                      42061
#
#                               replays_watched_counts total_hits   total_score  \
# 0  [{'count': 2, 'start_date': '2015-05-01'}, {'c...   28378396  367849125665
# 1  [{'count': 19, 'start_date': '2013-11-01'}, {'...   42410479  467840602465
# 2  [{'count': 1, 'start_date': '2014-11-01'}, {'c...   22063826  216798962074
# 3  [{'count': 4, 'start_date': '2015-05-01'}, {'c...   15468426  108398366502
# 4  [{'count': 22, 'start_date': '2012-01-01'}, {'...   30409606  327137749103
#
#       username
# 0        Mathi
# 1        Rafis
# 2  Donkey Kong
# 3      Azerite
# 4       Totoki
#
# [5 rows x 27 columns]

# %%
df.describe()
# Out:
#                  A             S            SS          age  country_rank  \
# count  9970.000000   9970.000000   9970.000000  6965.000000   9920.000000
# mean    777.333300    853.324373    121.371414    20.152620    363.108871
# std     447.847373    703.041600    307.260293    11.640365   1269.782336
# min      -1.000000      0.000000    -13.000000     0.000000      1.000000
# 25%     470.000000    448.250000     23.000000    17.000000     48.000000
# 50%     701.000000    672.000000     49.000000    19.000000    149.000000
# 75%     992.000000   1045.750000    111.000000    21.000000    368.000000
# max    5847.000000  15734.000000  13388.000000   103.000000  44563.000000
#
#        favourite_beatmapset_count  follower_count  hit_accuracy        level  \
# count                 9970.000000     9970.000000   9970.000000  9970.000000
# mean                    21.179639      232.230893     98.397059    97.492377
# std                     27.075644     1627.293983      1.508737    12.402469
# min                      0.000000        0.000000     39.822400     4.000000
# 25%                      1.000000       34.000000     98.222275   100.000000
# 50%                      9.000000       74.000000     98.716300   100.000000
# 75%                     31.000000      159.000000     99.042975   100.000000
# max                    100.000000    95465.000000    100.000000   107.000000
#
#        maximum_combo     play_count    play_time    post_count  \
# count    9970.000000    9970.000000  9970.000000   9970.000000
# mean     3241.913842   57309.096991   770.091653     49.043129
# std      1315.068422   34217.199866   428.855250    315.624712
# min        11.000000       3.000000     0.068889      0.000000
# 25%      2277.000000   35177.500000   505.676667      0.000000
# 50%      3033.000000   52219.000000   712.242778      2.000000
# 75%      3962.750000   73517.750000   967.971806     10.000000
# max     15464.000000  353971.000000  5159.530833  16091.000000
#
#        ranked_and_approved_beatmapset_count  ranked_score  \
# count                           9970.000000  9.970000e+03
# mean                               0.222869  1.605564e+10
# std                                2.978655  1.323792e+10
# min                                0.000000  1.662400e+05
# 25%                                0.000000  8.052487e+09
# 50%                                0.000000  1.293052e+10
# 75%                                0.000000  2.047307e+10
# max                              220.000000  2.695437e+11
#
#        replays_watched_by_others    total_hits   total_score
# count               9.970000e+03  9.970000e+03  9.970000e+03
# mean                5.864286e+03  1.153778e+07  8.873972e+10
# std                 9.824596e+04  6.630793e+06  7.018404e+10
# min                 0.000000e+00  1.368000e+03  4.623100e+05
# 25%                 2.000000e+01  7.292878e+06  4.573986e+10
# 50%                 7.400000e+01  1.042459e+07  7.175556e+10
# 75%                 3.580000e+02  1.458392e+07  1.114829e+11
# max                 6.472658e+06  5.551982e+07  7.676795e+11

# %% [markdown]
# ### deleting obviously unimportant fields

# %%
df = df.drop(['username', 'country', 'monthly_playcounts', 'previous_usernames', 'replays_watched_counts', "join_date"  ], axis=1)
df.head()
# Out:
#         A       S     SS   age  country_rank  favourite_beatmapset_count  \
# 0   651.0   803.0   28.0  16.0           1.0                          60
# 1  1034.0   405.0  189.0  19.0           1.0                          14
# 2   839.0   787.0   52.0  14.0           1.0                          10
# 3  1171.0   490.0   27.0   NaN           1.0                          61
# 4   912.0  3450.0  234.0  22.0           1.0                          51
#
#    follower_count  hit_accuracy  is_active  is_supporter      ...       \
# 0            9204       98.3008       True          True      ...
# 1           48041       98.9178       True          True      ...
# 2           17495       98.4025       True          True      ...
# 3            5413       99.0310       True          True      ...
# 4            5702       97.5871       True          True      ...
#
#    maximum_combo  play_count    play_time           playstyle post_count  \
# 0           5081      127203  1695.623333  [keyboard, tablet]          9
# 1           5086      237913  2667.041111  [keyboard, tablet]         15
# 2           5849      121355  1447.337500             [touch]         10
# 3           2393       71481   931.634722   [mouse, keyboard]         17
# 4           4215      122956  1748.853889  [keyboard, tablet]         94
#
#    ranked_and_approved_beatmapset_count  ranked_score  \
# 0                                     0   35956687428
# 1                                     0   46649498415
# 2                                     0   29827153244
# 3                                     0   15928388241
# 4                                     0   53430781951
#
#    replays_watched_by_others  total_hits   total_score
# 0                     188557    28378396  367849125665
# 1                    1720746    42410479  467840602465
# 2                     464031    22063826  216798962074
# 3                      93667    15468426  108398366502
# 4                      42061    30409606  327137749103
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Checking missing data (True field means we have missing data)

# %%
missing_data = df.isnull()
missing_data_test = df_test.isnull()

for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
    
#
# Out:
# A
# False    9970
# Name: A, dtype: int64
#
# S
# False    9970
# Name: S, dtype: int64
#
# SS
# False    9970
# Name: SS, dtype: int64
#
# age
# False    6965
# True     3005
# Name: age, dtype: int64
#
# country_rank
# False    9920
# True       50
# Name: country_rank, dtype: int64
#
# favourite_beatmapset_count
# False    9970
# Name: favourite_beatmapset_count, dtype: int64
#
# follower_count
# False    9970
# Name: follower_count, dtype: int64
#
# hit_accuracy
# False    9970
# Name: hit_accuracy, dtype: int64
#
# is_active
# False    9970
# Name: is_active, dtype: int64
#
# is_supporter
# False    9970
# Name: is_supporter, dtype: int64
#
# level
# False    9970
# Name: level, dtype: int64
#
# maximum_combo
# False    9970
# Name: maximum_combo, dtype: int64
#
# play_count
# False    9970
# Name: play_count, dtype: int64
#
# play_time
# False    9970
# Name: play_time, dtype: int64
#
# playstyle
# False    9471
# True      499
# Name: playstyle, dtype: int64
#
# post_count
# False    9970
# Name: post_count, dtype: int64
#
# ranked_and_approved_beatmapset_count
# False    9970
# Name: ranked_and_approved_beatmapset_count, dtype: int64
#
# ranked_score
# False    9970
# Name: ranked_score, dtype: int64
#
# replays_watched_by_others
# False    9970
# Name: replays_watched_by_others, dtype: int64
#
# total_hits
# False    9970
# Name: total_hits, dtype: int64
#
# total_score
# False    9970
# Name: total_score, dtype: int64

# %% [markdown]
# So we missing **"Playstyle" : 499**, **"age" : 3005** and **"country_rank" : 50** lets replace first one with word "Missing"  and last two with their means. Also we will convert "playstyle" array to a string

# %%
df["playstyle"].replace(np.nan, "Missing", inplace = True)

avg_age=df['age'].mean(axis=0)
df['age'].replace(np.nan, avg_age, inplace= True)

avg_rank=df['country_rank'].mean(axis=0)
df['country_rank'].replace(np.nan, avg_rank, inplace= True)

df["playstyle"] = df.playstyle.apply(lambda x: "-".join(x))

# %%
df.head()
# Out:
#         A       S     SS       age  country_rank  favourite_beatmapset_count  \
# 0   651.0   803.0   28.0  16.00000           1.0                          60
# 1  1034.0   405.0  189.0  19.00000           1.0                          14
# 2   839.0   787.0   52.0  14.00000           1.0                          10
# 3  1171.0   490.0   27.0  20.15262           1.0                          61
# 4   912.0  3450.0  234.0  22.00000           1.0                          51
#
#    follower_count  hit_accuracy  is_active  is_supporter      ...       \
# 0            9204       98.3008       True          True      ...
# 1           48041       98.9178       True          True      ...
# 2           17495       98.4025       True          True      ...
# 3            5413       99.0310       True          True      ...
# 4            5702       97.5871       True          True      ...
#
#    maximum_combo  play_count    play_time        playstyle post_count  \
# 0           5081      127203  1695.623333  keyboard-tablet          9
# 1           5086      237913  2667.041111  keyboard-tablet         15
# 2           5849      121355  1447.337500            touch         10
# 3           2393       71481   931.634722   mouse-keyboard         17
# 4           4215      122956  1748.853889  keyboard-tablet         94
#
#    ranked_and_approved_beatmapset_count  ranked_score  \
# 0                                     0   35956687428
# 1                                     0   46649498415
# 2                                     0   29827153244
# 3                                     0   15928388241
# 4                                     0   53430781951
#
#    replays_watched_by_others  total_hits   total_score
# 0                     188557    28378396  367849125665
# 1                    1720746    42410479  467840602465
# 2                     464031    22063826  216798962074
# 3                      93667    15468426  108398366502
# 4                      42061    30409606  327137749103
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Now lets check data types of our features, and see is there **Categorical variables**

# %%
df.dtypes
# Out:
# A                                       float64
# S                                       float64
# SS                                      float64
# age                                     float64
# country_rank                            float64
# favourite_beatmapset_count                int64
# follower_count                            int64
# hit_accuracy                            float64
# is_active                                  bool
# is_supporter                               bool
# level                                     int64
# maximum_combo                             int64
# play_count                                int64
# play_time                               float64
# playstyle                                object
# post_count                                int64
# ranked_and_approved_beatmapset_count      int64
# ranked_score                              int64
# replays_watched_by_others                 int64
# total_hits                                int64
# total_score                               int64
# dtype: object

# %% [markdown]
# We have 3 categorical values, **"Is_active"**, **"is_supporter"**, and **"playstyle"**
# Let's look at the relationship between them and "pp"

# %%
fig = plt.figure(figsize=(16,9)) # create figure

ax0 = fig.add_subplot(2, 2, 1)
ax1 = fig.add_subplot(222) 
ax2 = fig.add_subplot(223) 

# (remember! we need to take only training part of our data)
sns.boxplot(x=df.playstyle[:train_number], y=target, ax=ax0)
sns.boxplot(x=df.is_active[:train_number], y=target,  ax=ax1)
sns.boxplot(x=df.is_supporter[:train_number], y=target, ax=ax2)

# %% [markdown]
# The distributions of **"pp"** between **"Is_active", "is_supporter", "playstyle"** have a significant overlap, and so they would not be a good predictors, lets drop them

# %%
# drop categoricals, no info 
df.drop("playstyle", axis = 1, inplace=True)
df.drop("is_supporter", axis = 1, inplace=True)
df.drop("is_active", axis = 1, inplace=True)
df.head()
# Out:
#         A       S     SS       age  country_rank  favourite_beatmapset_count  \
# 0   651.0   803.0   28.0  16.00000           1.0                          60
# 1  1034.0   405.0  189.0  19.00000           1.0                          14
# 2   839.0   787.0   52.0  14.00000           1.0                          10
# 3  1171.0   490.0   27.0  20.15262           1.0                          61
# 4   912.0  3450.0  234.0  22.00000           1.0                          51
#
#    follower_count  hit_accuracy  level  maximum_combo  play_count  \
# 0            9204       98.3008    103           5081      127203
# 1           48041       98.9178    104           5086      237913
# 2           17495       98.4025    101           5849      121355
# 3            5413       99.0310    100           2393       71481
# 4            5702       97.5871    103           4215      122956
#
#      play_time  post_count  ranked_and_approved_beatmapset_count  \
# 0  1695.623333           9                                     0
# 1  2667.041111          15                                     0
# 2  1447.337500          10                                     0
# 3   931.634722          17                                     0
# 4  1748.853889          94                                     0
#
#    ranked_score  replays_watched_by_others  total_hits   total_score
# 0   35956687428                     188557    28378396  367849125665
# 1   46649498415                    1720746    42410479  467840602465
# 2   29827153244                     464031    22063826  216798962074
# 3   15928388241                      93667    15468426  108398366502
# 4   53430781951                      42061    30409606  327137749103

# %% [markdown]
# ### Normalization, simply deviding all freutures by their max value

# %%
df['A'] = df['A']/df['A'].max()
df['S'] = df['S']/df['S'].max()
df['SS'] = df['SS']/df['SS'].max()
df['age'] = df['age']/df['age'].max()
df['favourite_beatmapset_count'] = df['favourite_beatmapset_count']/df['favourite_beatmapset_count'].max()
df['follower_count'] = df['follower_count']/df['follower_count'].max()
df['hit_accuracy'] = df['hit_accuracy']/df['hit_accuracy'].max()
df['play_count'] = df['play_count']/df['play_count'].max()
df['play_time'] = df['play_time']/ df['play_time'].max()
df['post_count'] = df['post_count']/df['post_count'].max()
df['ranked_score'] = df['ranked_score']/df['ranked_score'].max()
df['replays_watched_by_others'] = df['replays_watched_by_others']/df['replays_watched_by_others'].max()
df['total_hits'] = df['total_hits']/df['total_hits'].max()
df['total_score'] = df['total_score']/df['total_score'].max()
df['level'] = df['level']/df['level'].max()
df['maximum_combo'] = df['maximum_combo']/df['maximum_combo'].max()

df.head()
# Out:
#           A         S        SS       age  country_rank  \
# 0  0.111339  0.051036  0.002091  0.155340           1.0
# 1  0.176843  0.025740  0.014117  0.184466           1.0
# 2  0.143492  0.050019  0.003884  0.135922           1.0
# 3  0.200274  0.031143  0.002017  0.195657           1.0
# 4  0.155977  0.219270  0.017478  0.213592           1.0
#
#    favourite_beatmapset_count  follower_count  hit_accuracy     level  \
# 0                        0.60        0.096412      0.983008  0.962617
# 1                        0.14        0.503232      0.989178  0.971963
# 2                        0.10        0.183261      0.984025  0.943925
# 3                        0.61        0.056701      0.990310  0.934579
# 4                        0.51        0.059729      0.975871  0.962617
#
#    maximum_combo  play_count  play_time  post_count  \
# 0       0.328570    0.359360   0.328639    0.000559
# 1       0.328893    0.672126   0.516915    0.000932
# 2       0.378233    0.342839   0.280517    0.000621
# 3       0.154747    0.201940   0.180566    0.001056
# 4       0.272569    0.347362   0.338956    0.005842
#
#    ranked_and_approved_beatmapset_count  ranked_score  \
# 0                                     0      0.133398
# 1                                     0      0.173068
# 2                                     0      0.110658
# 3                                     0      0.059094
# 4                                     0      0.198227
#
#    replays_watched_by_others  total_hits  total_score
# 0                   0.029131    0.511140     0.479170
# 1                   0.265848    0.763880     0.609422
# 2                   0.071691    0.397404     0.282408
# 3                   0.014471    0.278611     0.141203
# 4                   0.006498    0.547725     0.426138

# %% [markdown]
# ### we can calculate the correlation between variables (befor plotting i will remove outliers)

# %%
training_data = pd.concat([df[:train_number], target], axis=1)

no_outliers = training_data[(np.abs(stats.zscore(training_data)) < 3).all(axis=1)]

corr = no_outliers.corr()
fig, ax = plt.subplots(figsize=(25,10)) 
sns.heatmap(corr, xticklabels=corr.columns.values, annot=True, yticklabels=corr.columns.values, ax=ax)

# %% [markdown]
# In order to start understanding the (linear) relationship between an individual variable and the **pp**. We can do this by using "regplot", which plots the scatterplot plus the fitted regression line for the data

# %% [markdown]
# from previous plot we see that the lowest and highest correlation with **pp** have **ranked_and_approved_beatmapset_count**, and **total_score** so let's examine them

# %%
fig = plt.figure(figsize=(12, 6)) # create figure

ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122) 

sns.regplot(x="ranked_and_approved_beatmapset_count", y="pp", data=no_outliers, ax=ax1)
sns.regplot(x="total_score", y="pp", data=no_outliers, ax=ax2)

# %% [markdown]
# **ranked_and_approved_beatmapset_count**  does not seem like a good predictor of the **"pp"** at all so lets drop it

# %%
df.drop("ranked_and_approved_beatmapset_count", axis = 1, inplace=True)
df.drop("hit_accuracy", axis = 1, inplace=True)
# df.drop("SS", axis = 1, inplace=True)
# df.drop("A", axis = 1, inplace=True)
df.drop("S", axis = 1, inplace=True)
# df.drop("age", axis = 1, inplace=True)
# df.drop("favourite_beatmapset_count", axis = 1, inplace=True)
df.drop("level", axis = 1, inplace=True)
# df.drop("post_count", axis = 1, inplace=True)
df.drop("total_hits", axis = 1, inplace=True)
# df.drop("replays_watched_by_others", axis = 1, inplace=True)
df.drop("play_count", axis = 1, inplace=True)

print(df.shape)
df.head()
# Out:
# (9970, 12)
#           A        SS       age  country_rank  favourite_beatmapset_count  \
# 0  0.111339  0.002091  0.155340           1.0                        0.60
# 1  0.176843  0.014117  0.184466           1.0                        0.14
# 2  0.143492  0.003884  0.135922           1.0                        0.10
# 3  0.200274  0.002017  0.195657           1.0                        0.61
# 4  0.155977  0.017478  0.213592           1.0                        0.51
#
#    follower_count  maximum_combo  play_time  post_count  ranked_score  \
# 0        0.096412       0.328570   0.328639    0.000559      0.133398
# 1        0.503232       0.328893   0.516915    0.000932      0.173068
# 2        0.183261       0.378233   0.280517    0.000621      0.110658
# 3        0.056701       0.154747   0.180566    0.001056      0.059094
# 4        0.059729       0.272569   0.338956    0.005842      0.198227
#
#    replays_watched_by_others  total_score
# 0                   0.029131     0.479170
# 1                   0.265848     0.609422
# 2                   0.071691     0.282408
# 3                   0.014471     0.141203
# 4                   0.006498     0.426138

# %%
training_data = pd.concat([df[:train_number], target], axis=1)

print(training_data.shape)

training_no_outliers = training_data[(np.abs(stats.zscore(training_data)) < 3).all(axis=1)]
print(training_no_outliers.shape)
training_no_outliers.head()
# Out:
# (6976, 13)
# (6263, 13)
#             A        SS       age  country_rank  favourite_beatmapset_count  \
# 133  0.060544  0.005976  0.195657           6.0                        0.32
# 134  0.164871  0.012698  0.174757           9.0                        1.00
# 138  0.050282  0.001344  0.195657          15.0                        0.03
# 139  0.073371  0.000896  0.195657          15.0                        0.00
# 141  0.158885  0.004258  0.194175          20.0                        0.95
#
#      follower_count  maximum_combo  play_time  post_count  ranked_score  \
# 133        0.008988       0.232023   0.198315    0.001554      0.116492
# 134        0.002504       0.278453   0.095898    0.000000      0.123866
# 138        0.000922       0.387287   0.061691    0.000062      0.030826
# 139        0.001068       0.174082   0.160417    0.000062      0.041517
# 141        0.001718       0.328828   0.275951    0.000124      0.123262
#
#      replays_watched_by_others  total_score    pp
# 133                   0.000528     0.271694  9852
# 134                   0.000517     0.160882  9845
# 138                   0.000129     0.047288  9829
# 139                   0.000093     0.107377  9823
# 141                   0.000131     0.296269  9813

# %%
target_no_outliers = training_no_outliers['pp']
training_no_outliers = training_no_outliers.drop(["pp"], axis = 1)
print(target_no_outliers.shape)
print(training_no_outliers.shape)
# Out:
# (6263,)
# (6263, 12)

# %% [markdown]
# ### Finally the train, test sets and target are

# %%
y = np.array(target_no_outliers)
X = np.array(training_no_outliers)
X_t = np.array(df[train_number:])
usernames = np.array(test_usernames)

# %%
print(y.shape)
print(X.shape)
print(X_t.shape)
# Out:
# (6263,)
# (6263, 12)
# (2994, 12)

# %% [markdown]
# # Model creation

# %% [markdown]
# ### My models

# %%
from numpy.linalg import inv
from sklearn.model_selection import KFold
from sklearn.preprocessing import PolynomialFeatures

def RMSE(X, Y, b):

    return np.mean((X.dot(b) - Y) ** 2) ** (0.5)

def fit_linear_regression(X, Y, Lambda=0):

    # Identity matrix (number of parameters is the dimension)
    Identity = np.identity(len(X[1,:]))   
    # We don't add penalty to intercept
    Identity[0,0] = 0
    
    return inv(X.transpose().dot(X) + Lambda*Identity).dot(X.transpose()).dot(Y)

# %% [markdown]
# ### Linear

# %%
kf = KFold(n_splits=5, shuffle=True)
kf.get_n_splits(X)
means=[]

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    poly = PolynomialFeatures(1)
    X_train = poly.fit_transform(X_train)
    X_test = poly.fit_transform(X_test)
    beta = fit_linear_regression(X_train, y_train)
    mean_err = RMSE(X_test, y_test, beta)
    means.append(mean_err)
print("Cross Validation error:", np.mean(means))
# Out:
# Cross Validation error: 736.0291175293244

# %% [markdown]
# ### Polynomial

# %%
kf = KFold(n_splits=5, shuffle=True)
kf.get_n_splits(X)

for d in range(1, 4):    
    means_poly = []
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        poly = PolynomialFeatures(d)
        X_train_poly = poly.fit_transform(X_train)
        X_test_poly = poly.fit_transform(X_test)
        beta = fit_linear_regression(X_train_poly, y_train)
        mean_err = RMSE(X_test_poly, y_test, beta)
        means_poly.append(mean_err)
    print("RMSE for polynome degree :", d, "is:", np.mean(means_poly))
# Out:
# RMSE for polynome degree : 1 is: 737.1500494198692
# RMSE for polynome degree : 2 is: 734.415700213689
# RMSE for polynome degree : 3 is: 4017.4272600193226

# %% [markdown]
# ### Polynimial with Regularization

# %%
# kf = KFold(n_splits=5, shuffle=True)
# kf.get_n_splits(X)

# for d in range(1, 4):  
#     for a in np.arange(0, 10, 0.2):        
#         mean_tmp = []
#         for train_index, test_index in kf.split(X):
#             X_train, X_test = X[train_index], X[test_index]
#             y_train, y_test = y[train_index], y[test_index]
#             poly = PolynomialFeatures(d)
#             X_train_poly = poly.fit_transform(X_train)
#             X_test_poly = poly.fit_transform(X_test)
#             beta = fit_linear_regression(X_train_poly, y_train, a)
#             mean_err = RMSE(X_test_poly, y_test, beta)
#             mean_tmp.append(mean_err)
#         print("RMSE for polinom degree:", d, "and lambda:", a, "is : ", np.mean(mean_tmp))

# %%
kf = KFold(n_splits=5, shuffle=True)
kf.get_n_splits(X)

for a in np.arange(0, 0.1, 0.02):        
        mean_tmp = []
        for train_index, test_index in kf.split(X):
            X_train, X_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]
            poly = PolynomialFeatures(3)
            X_train_poly = poly.fit_transform(X_train)
            X_test_poly = poly.fit_transform(X_test)
            beta = fit_linear_regression(X_train_poly, y_train, a)
            mean_err = RMSE(X_test_poly, y_test, beta)
            mean_tmp.append(mean_err)
        print("RMSE for polinom degree:", 3, "and lambda:", a, "is : ", np.mean(mean_tmp))
# Out:
# RMSE for polinom degree: 3 and lambda: 0.0 is :  8573.632084239745
# RMSE for polinom degree: 3 and lambda: 0.02 is :  694.2229110551788
# RMSE for polinom degree: 3 and lambda: 0.04 is :  687.5297122222021
# RMSE for polinom degree: 3 and lambda: 0.06 is :  686.0800249564045
# RMSE for polinom degree: 3 and lambda: 0.08 is :  689.1695793544852

# %% [markdown]
# #### The best model is for polinom degree: 3 and lambda: 1

# %% [markdown]
# ## With Sklearn regression models

# %%
from sklearn import linear_model
from sklearn.model_selection import KFold
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ### Linear

# %%
# kf = KFold(n_splits=5, shuffle=True)
# kf.get_n_splits(X)
# means=[]

# for train_index, test_index in kf.split(X):
#     X_train, X_test = X[train_index], X[test_index]
#     y_train, y_test = y[train_index], y[test_index]
#     reg = linear_model.LinearRegression()
#     reg = reg.fit(X_train, y_train)
#     predict = reg.predict(X_test)
#     mean_err = np.mean((predict - y_test) ** 2) ** 0.5
#     means.append(mean_err)
# print("Cross Validation error:", np.mean(means))

# %% [markdown]
# ### Polynomial

# %%
# kf = KFold(n_splits=5, shuffle=True)
# kf.get_n_splits(X)

# for d in range(1, 4):    
#     means_poly = []
#     for train_index, test_index in kf.split(X):
#         X_train, X_test = X[train_index], X[test_index]
#         y_train, y_test = y[train_index], y[test_index]
#         poly = PolynomialFeatures(d)
#         X_train_poly = poly.fit_transform(X_train)
#         X_test_poly = poly.fit_transform(X_test)
#         reg = linear_model.LinearRegression()
#         reg = reg.fit(X_train_poly, y_train)
#         predict = reg.predict(X_test_poly)
#         means_poly.append(np.mean((predict - y_test) ** 2) ** (0.5))
#     print("RMSE for polynome degree :", d, "is:", np.mean(means_poly))

# %% [markdown]
# ### Polynimial with Regularization

# %%
# kf = KFold(n_splits=5, shuffle=True)
# kf.get_n_splits(X)

# for d in range(1, 4):  
#     for a in range(0, 5, 1):
        
#         mean_tmp = 0
#         for train_index, test_index in kf.split(X):
#             X_train, X_test = X[train_index], X[test_index]
#             y_train, y_test = y[train_index], y[test_index]
#             poly = PolynomialFeatures(d)
#             X_train_poly = poly.fit_transform(X_train)
#             X_test_poly = poly.fit_transform(X_test)
#             reg = linear_model.Ridge(alpha = a)
#             reg = reg.fit(X_train_poly, y_train)
#             predict = reg.predict(X_test_poly)
#             mean_tmp+= np.mean((predict - y_test) ** 2) ** (0.5)
#         print("RMSE for polinom degree:", d, "and lambda:", a, "is : ", mean_tmp/5 )

# %% [markdown]
# ### Prediction for real test set

# %%
print(X_t.shape)
print(usernames.shape)
# Out:
# (2994, 12)
# (2994,)

# %%
poly = PolynomialFeatures(1)
X_poly = poly.fit_transform(X)
X_t_poly = poly.fit_transform(X_t)

beta = fit_linear_regression(X_poly, y)
print(beta.shape)
print(X_poly.shape)
predictions = X_t_poly.dot(beta)
print(predictions.shape)
# Out:
# (13,)
# (74, 13)
# (2994,)

# %%
result_df = pd.concat([pd.DataFrame(list(usernames)), pd.DataFrame(list(predictions))], axis=1)
result_df.to_csv("Tigran_Vardanyan_predictions.csv")
result_df.head(20)
# Out:
#                  0             0
# 0         Cookiezi  64221.221157
# 1       filsdelama  12375.831375
# 2        firebat92  22114.016114
# 3             idke   9145.676652
# 4          Abyssal   8150.213543
# 5         hvick225  29772.604771
# 6   Freddie Benson   6863.225384
# 7            Dumii   6493.637878
# 8        fieryrage   8328.142000
# 9           Piggey   6808.845469
# 10           DanyL   7650.872487
# 11      MoeYandere   6251.624416
# 12         Monko2k   5975.733981
# 13             Kip   6864.506349
# 14         -Hebel-   6515.528710
# 15         ThePooN  10589.957302
# 16     Arnold24x24   6668.422586
# 17          Wilchq   8131.064597
# 18           Musty   9761.595475
# 19          Adamqs   6992.605669
